# %%
import pandas as pd
import matplotlib.pyplot as plt
file_path = '../data.csv'  
df = pd.read_csv(file_path)
# df

# %%
df
# Out:
#                file_name USER_NUMBER  begin  end wrong_word correct_word  \
# 0     sh_essay_10_28.txt  4011714021    822  826       دارد        دارد،
# 1     sh_essay_10_28.txt  4011714021    398  405    نه باید        نباید
# 2     sh_essay_10_28.txt  4011714021    394  397        کند         کند،
# 3     sh_essay_10_28.txt  4011714021    364  371    نه باید        نباید
# 4     sh_essay_10_28.txt  4011714021    364  371    نه باید        نباید
# ...                  ...         ...    ...  ...        ...          ...
# 9202   z_essay_16_25.txt   981714019    286  289        هست         هست.
# 9203   z_essay_16_25.txt   981714019    300  303        گلا        گل ها
# 9204   z_essay_16_25.txt   981714019    314  320     گلاهای       گل های
# 9205   z_essay_16_25.txt   981714019    332  339    می بنیم      می بینم
# 9206    z_essay_19_9.txt   981714019     62   66       سیاه        سیاحه
#
#                                          wrong_sentence  \
# ...

# %%
filtered_df_1 = df[(df['main_category'] == 'Punctuation') & (df['sub_category_1'] == 'Boundary') & (df['process'] == 'Omission')]

# %%
indices_to_drop =df[(df['main_category'] == 'Diacritic signs') & (df['sub_category_1'] == 'Tanwin') & (df['process'] == 'Omission')].index

# %%
df = df.drop(indices_to_drop)

# %%
indices_to_drop =df[(df['main_category'] == 'Diacritic signs') & (df['sub_category_1'] == 'Tashdid') & (df['process'] == 'Omission')].index

# %%
df = df.drop(indices_to_drop)

# %%
# indices_to_drop =df[(df['main_category'] == 'Diacritic signs') & (df['sub_category_1'] == 'Tashdid') & (df['process'] == 'Omission')].index

# %%
# filtered_df_1 = df[(df['correct_word'].isna())]

# %%
# filtered_df_1

# %%
df.to_csv('../data.csv', encoding='utf-8',index=False)

# %%
# filtered_df_1.to_csv('errror.csv', index=False)

# %%
file_path = './error.csv'  
error = pd.read_csv(file_path)

# %%
error
# Out:
#             file_name USER_NUMBER  begin  end wrong_word  correct_word  \
# 0    SFLC_LC_1865.txt   981724026    244  247        پثم           NaN
# 1    SFLC_LC_1855.txt       admin    321  324        است           NaN
# 2    sh_essay_7_0.txt   971714039    262  265        خود           NaN
# 3   z_essay_14_11.txt   981714019    807  808          -           NaN
# 4   z_essay_12_27.txt       admin    238  244     رایانه           NaN
# 5   z_essay_12_27.txt       admin    235  237         یک           NaN
# 6    SFLC_LC_1602.txt       admin    180  184       وزیت           NaN
# 7    SFLC_LC_1602.txt       admin    249  256    مهروبان           NaN
# 8    SFLC_LC_1602.txt       admin    240  242         به           NaN
# 9    SFLC_LC_1602.txt       admin    217  223     میبینم           NaN
# 10   SFLC_LC_1602.txt       admin    195  201     داشتنه           NaN
# 11   SFLC_LC_1602.txt       admin      6   12     سلامتی           NaN
# ...

# %%
# filtered_df = error[error['main_category'] != 'Punctuation']
# filtered_df = filtered_df[filtered_df['main_category'] != 'Diacritic signs']
# filtered_df = filtered_df[filtered_df['main_category'] != 'Diacritic signs']
# filtered_df
